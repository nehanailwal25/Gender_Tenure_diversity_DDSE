# %% [markdown]
# # Analysis of the data

# %%
#importing the needed libraries

import pandas as pd
import json
import csv
import xlsxwriter

import warnings
import sklearn.exceptions
warnings.filterwarnings("ignore", category=sklearn.exceptions.UndefinedMetricWarning)

import warnings
warnings.filterwarnings('ignore')

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols

import seaborn

# %% [markdown]
# ### Users data for whole Gender Analysis in the Github projects.

# %%
# Extracting the final set of data for doing the Analysis further

dataset = pd.read_csv(r"E:\Data\datasets\Project_data.csv");
dataset.head()
# Out:
#    user id       Username                       Fullname  \
# 0     1014       egranata                 Enrico Granata
# 1     1716       mtrienis                   Mike Trienis
# 2     3181         erszcz              Radek Szymczyszyn
# 3     5315       smfrench                   Steve French
# 4     5919  state-hiu-dev  Humanitarian Information Unit
#
#                   Firstname     Lastname   Gender                   Company  \
# 0                    Enrico      Granata     male                  @google
# 1                      Mike      Trienis     male             Quickinsights
# 2                     Radek  Szymczyszyn     male          Erlang Solutions
# 3                     Steve     French\n     male                 Microsoft
# 4  Humanitarian Information       Unit\n  unknown  U.S. Department of State
#
#   Company_Size  Start Date User Type  publc gists  Following     Column8  \
# 0        Large  10/24/2015       USR            0          0 -121.955236
# 1        Large  12/19/2016       USR            0          0 -123.043999
# 2        Small   1/26/2016       USR            0          0   19.944980
# 3        Large   10/7/2015       USR            0          0  -97.743061
# 4        Large   8/13/2015       USR            0          0  -77.036871
#
#      Column9 Country                  City        City2     Full address
# 0  37.354108      us    Santa Clara County  Santa Clara  Santa Clara, CA
# 1  49.281101      ca                    BC    Vancouver        Vancouver
# 2  50.064650      pl        Krak??w County      Krak??w   Cracow, Poland
# 3  30.267153      us         Travis County       Austin           Austin
# 4  38.907192      us  District of Columbia   Washington   Washington, DC

# %%
# Removing the unnecessary data from the dataset

dataset.drop(dataset.index[dataset['Gender'] == 'mostly_female'],axis=0, inplace = True)
dataset.drop(dataset.index[dataset['Gender'] == 'unknown'],axis=0, inplace = True)
dataset.drop(dataset.index[dataset['Gender'] == 'mostly_male'],axis=0, inplace = True)
dataset.dropna()
dataset.head()
# Out:
#    user id  Username           Fullname Firstname     Lastname  Gender  \
# 0     1014  egranata     Enrico Granata    Enrico      Granata    male
# 1     1716  mtrienis       Mike Trienis      Mike      Trienis    male
# 2     3181    erszcz  Radek Szymczyszyn     Radek  Szymczyszyn    male
# 3     5315  smfrench       Steve French     Steve     French\n    male
# 6    11501  HAIL9000      Hailee Kenney    Hailee     Kenney\n  female
#
#             Company Company_Size  Start Date User Type  publc gists  \
# 0          @google         Large  10/24/2015       USR            0
# 1     Quickinsights        Large  12/19/2016       USR            0
# 2  Erlang Solutions        Small   1/26/2016       USR            0
# 3         Microsoft        Large   10/7/2015       USR            0
# 6         Bright.md        Small    8/9/2015       USR            0
#
#    Following     Column8    Column9 Country                City        City2  \
# 0          0 -121.955236  37.354108      us  Santa Clara County  Santa Clara
# 1          0 -123.043999  49.281101      ca                  BC    Vancouver
# 2          0   19.944980  50.064650      pl      Krak??w County      Krak??w
# 3          0  -97.743061  30.267153      us       Travis County       Austin
# 6          0 -122.658719  45.512231      us    Multnomah County     Portland
#
#       Full address
# 0  Santa Clara, CA
# 1        Vancouver
# 2   Cracow, Poland
# 3           Austin
# 6     Portland, OR

# %% [markdown]
# ## RQ-1: Male to Female Ratio in Github projects

# %%
#Importing needed liberaries

import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Male to Female Ratio in Github projects

dataset.Gender.value_counts().plot(kind='pie',autopct='%1.1f%%')
# Out:
# <AxesSubplot:ylabel='Gender'>

# %%
#To get the top five companies from the dataset

dataset.Company.value_counts()
# Out:
# Microsoft                      318
# IBM                            130
# Microsoft Corporation           67
# Student                         65
# Google                          64
#                               ...
# Graham Technologies              1
# The Tech Academy - Portland      1
# Jonah Group                      1
# Foothill College                 1
# Luzly                            1
# Name: Company, Length: 22843, dtype: int64

# %%
#Data for top five companies in the dataframe

top_5_companies= ['Microsoft','IBM','Microsoft Corporation','Student','Google']
companies_dataset = dataset.loc[dataset['Company'].isin(top_5_companies)]
companies_dataset
# Out:
#          user id         Username             Fullname   Firstname  \
# 3           5315         smfrench         Steve French       Steve
# 57        254667  michael-holzheu      Michael Holzheu     Michael
# 161       958907        henrynash           Henry Nash       Henry
# 170      1025081        mlippautz     Michael Lippautz     Michael
# 194      1204375        maheshsal    Mahesh Salgaonkar      Mahesh
# ...          ...              ...                  ...         ...
# 190096  40523301       JoshJettie        Joshua Jettie      Joshua
# 191181  41091405     ChrisLopezUK         Luke Stanton        Luke
# 191188  41094065  senthil-rajaram        Brian Quirion       Brian
# 191240  41119304     jpmulhol-ibm  Constantin Munteanu  Constantin
# 191391  41203412  josiahblaisdell        Oliver Watson      Oliver
#
#             Lastname Gender                Company Company_Size Start Date  \
# 3           French\n   male              Microsoft        Large  10/7/2015
# 57         Holzheu\n   male                    IBM        Large  8/22/2015
# 161           Nash\n   male                    IBM        Large   3/2/2015
# 170       Lippautz\n   male                 Google        Large   3/8/2015
# 194     Salgaonkar\n   male                    IBM        Large  8/22/2015
# ...              ...    ...                    ...          ...        ...
# 190096      Jettie\n   male                Student        Large  8/23/2016
# 191181     Stanton\n   male  Microsoft Corporation        Large  11/1/2016
# 191188     Quirion\n   male  Microsoft Corporation        Large   8/8/2016
# 191240    Munteanu\n   male                    IBM        Large  2/23/2016
# 191391      Watson\n   male                Student        Large   1/9/2016
#
#        User Type  publc gists  Following     Column8    Column9 Country  \
# 3            USR            0          0  -97.743061  30.267153      us
# 57           USR            0          0    9.008830  48.681331      de
# 161          USR            0          0   -2.587910  51.454513      gb
# 170          USR            0          0   11.581981  48.135125      de
# 194          USR            0          0   77.594563  12.971599      in
# ...          ...          ...        ...         ...        ...     ...
# 190096       USR            0          0  -79.931602  32.781151      us
# 191181       USR            0          0   -0.963010  51.453522      gb
# 191188       USR            0          0 -122.329453  47.603569      us
# 191240       USR            0          0  -77.616318  43.155800      us
# 191391       USR            0          0  -96.325897  30.620541      us
#
#                    City            City2         Full address
# 3         Travis County           Austin               Austin
# 57           B??blingen       B??blingen           B??blingen
# 161     City of Bristol          Bristol          Bristol, UK
# 170       Upper Bavaria           Munich               Munich
# 194     Bangalore Urban        Bengaluru    Bangalore, India.
# ...                 ...              ...                  ...
# 190096               SC       Charleston        Charleston SC
# 191181          England          Reading          Reading, UK
# 191188               WA          Seattle              Seattle
# 191240               NY        Rochester            Rochester
# 191391               TX  College Station  College Station, TX
#
# [644 rows x 18 columns]

# %%
#Top five companies analysis

sns.countplot(x='Company',hue='Gender',data=companies_dataset)
sns.set(rc={'figure.figsize':(10,10)})
plt.title("Male and Female Ratios in top 5 companies")
# Out:
# Text(0.5, 1.0, 'Male and Female Ratios in top 5 companies')

# %% [markdown]
# # RQ-2: Gender and Project Tenure

# %%
projects_dataset = pd.read_csv(r"E:\Data\DATA_FINAL\Projects_tenure_size_gender_dataset.csv");
projects_dataset.head()
# Out:
#     User_id      Username  Gender  Repo_id commit_date Project_size  \
# 0    376214   VorontsovIE    male     4592   2/25/2015        Small
# 1   6836847   jeremiah-de    male     4661   1/21/2016        Small
# 2  10159279  mkacherovich    male    15333  11/11/2015        Small
# 3   7076783         ajlam  female    25521  10/14/2015        Small
# 4   8712122    openx-luis    male    29067   8/12/2015        Small
#
#   Project_Tenure
# 0       One Year
# 1       One Year
# 2       One Year
# 3       One Year
# 4       One Year

# %%
projects_dataset.shape
# Out:
# (12562, 7)

# %%
projects_dataset["Project_Tenure"].value_counts()
# Out:
# One Year     12375
# Two Years      187
# Name: Project_Tenure, dtype: int64

# %%
sns.countplot(x='Project_Tenure',hue='Gender',data=projects_dataset)
sns.set(rc={'figure.figsize':(10,10)})
plt.title("Male and Female Ratios according to Project Tenure")
# Out:
# Text(0.5, 1.0, 'Male and Female Ratios according to Project Tenure')

# %%
#data for statistical modelling

projects_dataset_b = pd.read_csv(r"E:\Data\DATA_FINAL\Projects_tenure_size_gender_dataset_b.csv");
projects_dataset_b.head()
# Out:
#     User_id      Username  Gender  Repo_id commit_date Project_size  \
# 0    376214   VorontsovIE       0     4592   2/25/2015        Small
# 1   6836847   jeremiah-de       0     4661   1/21/2016        Small
# 2  10159279  mkacherovich       0    15333  11/11/2015        Small
# 3   7076783         ajlam       1    25521  10/14/2015        Small
# 4   8712122    openx-luis       0    29067   8/12/2015        Small
#
#   Project_Tenure
# 0       One Year
# 1       One Year
# 2       One Year
# 3       One Year
# 4       One Year

# %%
mod=ols('Gender ~ Project_Tenure',data=projects_dataset_b).fit()
aov_table=sm.stats.anova_lm(mod, type=2)
print(aov_table)
# Out:
#                      df       sum_sq   mean_sq          F        PR(>F)
# Project_Tenure      1.0     3.170031  3.170031  24.349751  8.136716e-07
# Residual        12560.0  1635.153882  0.130187        NaN           NaN

# %%
projects_dataset.apply(lambda x: x.factorize()[0]).corr(method='pearson')
# Out:
#                  User_id  Username    Gender   Repo_id  commit_date  \
# User_id         1.000000  1.000000  0.025233  0.743954     0.334003
# Username        1.000000  1.000000  0.025233  0.743954     0.334003
# Gender          0.025233  0.025233  1.000000  0.020438     0.007635
# Repo_id         0.743954  0.743954  0.020438  1.000000     0.377233
# commit_date     0.334003  0.334003  0.007635  0.377233     1.000000
# Project_size    0.002143  0.002143  0.032137 -0.018317     0.027345
# Project_Tenure  0.017853  0.017853  0.043988 -0.013793    -0.000635
#
#                 Project_size  Project_Tenure
# User_id             0.002143        0.017853
# Username            0.002143        0.017853
# Gender              0.032137        0.043988
# Repo_id            -0.018317       -0.013793
# commit_date         0.027345       -0.000635
# Project_size        1.000000        0.758878
# Project_Tenure      0.758878        1.000000

# %% [markdown]
# # RQ-3: Gender Diversity and Project Team size

# %%
projects_dataset = pd.read_csv(r"E:\Data\DATA_FINAL\Projects_tenure_size_gender_dataset.csv");
projects_dataset.head()
# Out:
#     User_id      Username  Gender  Repo_id commit_date Project_size  \
# 0    376214   VorontsovIE    male     4592   2/25/2015        Small
# 1   6836847   jeremiah-de    male     4661   1/21/2016        Small
# 2  10159279  mkacherovich    male    15333  11/11/2015        Small
# 3   7076783         ajlam  female    25521  10/14/2015        Small
# 4   8712122    openx-luis    male    29067   8/12/2015        Small
#
#   Project_Tenure
# 0       One Year
# 1       One Year
# 2       One Year
# 3       One Year
# 4       One Year

# %%
projects_dataset["Project_size"].value_counts()
# Out:
# Small     11933
# Middle      469
# Large       160
# Name: Project_size, dtype: int64

# %%
sns.countplot(x='Project_size',hue='Gender',data=projects_dataset)
sns.set(rc={'figure.figsize':(5,5)})
plt.title("Male and Female Ratios according to Team Sizes")
# Out:
# Text(0.5, 1.0, 'Male and Female Ratios according to Team Sizes')

# %%
#Statistical modeling of data

projects_dataset_b = pd.read_csv(r"E:\Data\DATA_FINAL\Projects_tenure_size_gender_dataset_b.csv");
projects_dataset_b.head()
# Out:
#     User_id      Username  Gender  Repo_id commit_date Project_size  \
# 0    376214   VorontsovIE       0     4592   2/25/2015        Small
# 1   6836847   jeremiah-de       0     4661   1/21/2016        Small
# 2  10159279  mkacherovich       0    15333  11/11/2015        Small
# 3   7076783         ajlam       1    25521  10/14/2015        Small
# 4   8712122    openx-luis       0    29067   8/12/2015        Small
#
#   Project_Tenure
# 0       One Year
# 1       One Year
# 2       One Year
# 3       One Year
# 4       One Year

# %%
projects_dataset["Project_size"].value_counts()
# Out:
# Small     11933
# Middle      469
# Large       160
# Name: Project_size, dtype: int64

# %%
mod=ols('Gender ~ C(Project_size)',data=projects_dataset_b).fit()
aov_table=sm.stats.anova_lm(mod, type=2)
print(aov_table)
# Out:
#                       df       sum_sq   mean_sq       F    PR(>F)
# C(Project_size)      2.0     2.408296  1.204148  9.2443  0.000097
# Residual         12559.0  1635.915617  0.130258     NaN       NaN

# %%
projects_dataset.apply(lambda x: x.factorize()[0]).corr(method='pearson')
# Out:
#                  User_id  Username    Gender   Repo_id  commit_date  \
# User_id         1.000000  1.000000  0.025233  0.743954     0.334003
# Username        1.000000  1.000000  0.025233  0.743954     0.334003
# Gender          0.025233  0.025233  1.000000  0.020438     0.007635
# Repo_id         0.743954  0.743954  0.020438  1.000000     0.377233
# commit_date     0.334003  0.334003  0.007635  0.377233     1.000000
# Project_size    0.002143  0.002143  0.032137 -0.018317     0.027345
# Project_Tenure  0.017853  0.017853  0.043988 -0.013793    -0.000635
#
#                 Project_size  Project_Tenure
# User_id             0.002143        0.017853
# Username            0.002143        0.017853
# Gender              0.032137        0.043988
# Repo_id            -0.018317       -0.013793
# commit_date         0.027345       -0.000635
# Project_size        1.000000        0.758878
# Project_Tenure      0.758878        1.000000

# %%
plt.figure(figsize=(7,7))
seaborn.heatmap(projects_dataset.apply(lambda x: x.factorize()[0]).corr(), annot=True, cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
heatmap_data = projects_dataset[['Gender', 'Project_size', 'Project_Tenure']].copy()

# %%
plt.figure(figsize=(7,7))
seaborn.heatmap(heatmap_data.apply(lambda x: x.factorize()[0]).corr(), annot=True, cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Ratio of gender diversity with Company size

# %%
# Analysing the Relationship between gender diversity and Team Size

sns.countplot(x='Company_Size',hue='Gender',data=dataset)
sns.set(rc={'figure.figsize':(10,10)})
plt.title("Male and Female Ratios according to Company Sizes")
# Out:
# Text(0.5, 1.0, 'Male and Female Ratios according to Company Sizes')
